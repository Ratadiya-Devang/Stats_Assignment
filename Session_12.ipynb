# %%
import numpy as np

A=np.array([[120,150],[180,200]])
B=np.array([[30,40],[50,60]])
result=A@B
print(result)
# Out:
# [[11100 13800]
#  [15400 19200]]

# %%
def linear_regression_predict(x,m,c):
    return m*x+c

print(linear_regression_predict(5,2,3))
# Out:
# 13

# %%
def linear_regression_predict(x,m,c):
    return m*x+c

distances=[2,5,8]
for d in distances:
    print(f"Distance: {d} km -> Delivery Time: {linear_regression_predict(d,4,10)} minutes")
# Out:
# Distance: 2 km -> Delivery Time: 18 minutes
# Distance: 5 km -> Delivery Time: 30 minutes
# Distance: 8 km -> Delivery Time: 42 minutes

# %%
Slope='''The slope shows how much the predicted product price changes when the product rating increases by one unit.
A higher slope means the price changes more for each increase in rating.'''

Intercept='''
The intercept is the predicted product price when the rating is zero. It acts as the starting value of the prediction line before 
the effect of the rating is added.'''

print(Slope)
print()
print(Intercept)
# Out:
# The slope shows how much the predicted product price changes when the product rating increases by one unit.
# A higher slope means the price changes more for each increase in rating.
#
#
# The intercept is the predicted product price when the rating is zero. It acts as the starting value of the prediction line before
# the effect of the rating is added.

# %%
summary="""Matrix multiplication combines input data with model weights to produce predictions. During training, machine learning models
 repeatedly use matrix multiplication to process large amounts of data efficiently. In a song recommendation system like Spotify, it helps 
 compare user preferences with song features to generate personalized recommendations. This makes training faster and scalable for millions 
 of users and songs."""
print(summary)
# Out:
# Matrix multiplication combines input data with model weights to produce predictions. During training, machine learning models
#  repeatedly use matrix multiplication to process large amounts of data efficiently. In a song recommendation system like Spotify, it helps
#  compare user preferences with song features to generate personalized recommendations. This makes training faster and scalable for millions
#  of users and songs.
