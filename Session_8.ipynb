# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# 1. Write a Python function calculate_probability(event_count, total_outcomes) that returns the probability of an event, and use it to
#  find the probability of getting 'Heads' when tossing a coin.



def probablity(event,total):
    if  total == 0:
        return print("your total outcome is 0")
    else:
        return event/total 


event_count = 1
total_count =2 

ans = probablity(event_count,total_count)
print("probablity of head is := ",ans)
# Out:
# probablity of head is :=  0.5

# %%
# 2.# Simulate rolling a six-sided dice 100 times using Python's random module, count how many times a '6' appears, and calculate the experimental 
# probability of getting a '6'.<br><br><em><strong>Hint:</strong> Use random.randint(1,6) in a loop and keep a counter for '6'.</em>
import random

rolling_count =100

six_count = 0
for i in range(rolling_count):
    rolls = random.randint(1,6)

    if rolls == 6 :
        six_count+=1
    

print("total count to the rolling = ",rolling_count)
print("how many time 6 was happen =",six_count)
print("experimental probablity is = ",six_count/rolling_count)
# Out:
# total count to the rolling =  100
# how many time 6 was happen = 26
# experimental probablity is =  0.26

# %%
# 3. Given an array of genres from your last 20 Spotify songs (like ['pop', 'rock', 'pop', 'hiphop', ...]), write code to calculate the 
# probability of randomly picking a 'pop' song from your recent history.

genres = [
    'pop', 'rock', 'pop', 'hiphop', 'jazz',
    'pop', 'rock', 'classical', 'pop', 'hiphop',
    'pop', 'rock', 'pop', 'jazz', 'pop',
    'rock', 'pop', 'hiphop', 'pop', 'classical'
]


pop_count = genres.count('pop')

total_count = len(genres)


probality_genres = pop_count/total_count

print("pop count of list is =",pop_count)
print("total count of list is =",total_count)
print("probablity of the pop count is = ",probality_genres)
# Out:
# pop count of list is = 9
# total count of list is = 20
# probablity of the pop count is =  0.45

# %%
# 4. Write a function that, given two arrays — one for users who ordered food on Zomato and one for users who ordered dessert — 
# calculates the probability that a randomly selected user ordered both food and dessert (i.e., intersection over total unique users).


def probablity(list1,list2):
    both_users = set(list1).intersection(set(list2))
    total_users = set(list1).union(set(list2))

    probablity = len(both_users)/len(total_users)

    return both_users,total_users,probablity


food_users = [
    "Amit", "Rahul", "Priya", "Neha", "Riya",
    "Karan", "Sneha", "Vikas"
]

dessert_users = [
    "Rahul", "Neha", "Vikas", "Ankit",
    "Riya", "Pooja"
]


both_users,total_users,probablity = probablity(food_users,dessert_users)

print("both users = ",both_users)
print("total users =",total_users)
print("probablity is =" , probablity)
# Out:
# both users =  {'Rahul', 'Vikas', 'Neha', 'Riya'}
# total users = {'Pooja', 'Vikas', 'Priya', 'Ankit', 'Riya', 'Sneha', 'Karan', 'Rahul', 'Neha', 'Amit'}
# probablity is = 0.4

# %%
# 5. Explain with a short Python code example how conditional probability could be used to improve recommendations in an app like#  Flipkart
# (e.g., probability of buying headphones given user bought a phone).<br><br><em><strong>Hint:</strong> Use counts of users who bought both
# items vs total who bought a phone.</em>


def probablity_phone(both_buyer,phone_buyer):
    if phone_buyer == 0:
        print("they phone buyer is zero value")
    else:
        return both_buyer/phone_buyer



both = 35
phone = 100

probablity = probablity_phone(both,phone)
print("probablity of headphones and phone = ",probablity)
# Out:
# probablity of headphones and phone =  0.35
