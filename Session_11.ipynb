# %%
# 1.Create a Python list to represent a playlist of 5 song durations in seconds (e.g., [210, 180, 245, 200, 175]). Print the total duration of the
# playlist.

li = [210, 180, 245, 200, 175]

sumli = sum(li)
print(sumli)
# Out:
# 1010

# %%
#2.Represent a 3x3 matrix in Python to store the ratings (1-5) given by 3 friends to 3 different food items on Swiggy. Print the matrix and display
#the rating each friend gave to the second food item.


ratings = [
    [5, 4, 3],   
    [4, 5, 2],   
    [3, 4, 5]    
]

print("Ratings Matrix:")
for row in ratings:
    print(row)

print("\nRatings for the Second Food Item:")

print("Friend 1:", ratings[0][1])
print("Friend 2:", ratings[1][1])
print("Friend 3:", ratings[2][1])
# Out:
# Ratings Matrix:
# [5, 4, 3]
# [4, 5, 2]
# [3, 4, 5]
#
# Ratings for the Second Food Item:
# Friend 1: 4
# Friend 2: 5
# Friend 3: 4

# %%
# 3.Given a matrix representing the number of orders for 4 different dishes across 3 days (rows: days, columns: dishes), write code to calculate 
# and print the total orders for each dish.


orders = [
    [20, 15, 18, 10],   
    [25, 12, 20, 15],   
    [18, 20, 22, 12]    
]


print("Orders Matrix:")
for row in orders:
    print(row)

print("\nTotal Orders for Each Dish:")

for dish in range(len(orders[0])):
    total = 0

    for day in range(len(orders)):
        total += orders[day][dish]

    print("Dish", dish + 1, ":", total)
# Out:
# Orders Matrix:
# [20, 15, 18, 10]
# [25, 12, 20, 15]
# [18, 20, 22, 12]
#
# Total Orders for Each Dish:
# Dish 1 : 63
# Dish 2 : 47
# Dish 3 : 60
# Dish 4 : 37

# %%
# 4.Imagine you have a table of 5 Flipkart products with columns for price and quantity sold. Represent this data as a matrix in Python, then write 
# a function to calculate the total revenue for each product.<br><br><em><strong>Hint:</strong> Multiply price and quantity for each row, then print
#  the results.</em>




products = [
    [25000, 5],   
    [1500, 20],   
    [800, 30],    
    [12000, 8],   
    [500, 50]     
]

def calculate_revenue(product_matrix):

    print("Revenue of Each Product:\n")

    for i in range(len(product_matrix)):
        price = product_matrix[i][0]
        quantity = product_matrix[i][1]

        revenue = price * quantity

        print("Product", i + 1, "Revenue = ₹", revenue)

calculate_revenue(products)
# Out:
# Revenue of Each Product:
#
# Product 1 Revenue = ₹ 125000
# Product 2 Revenue = ₹ 30000
# Product 3 Revenue = ₹ 24000
# Product 4 Revenue = ₹ 96000
# Product 5 Revenue = ₹ 25000
