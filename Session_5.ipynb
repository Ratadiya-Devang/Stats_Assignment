# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import random

# %%
# 1.List 3 examples of 'population' and 'sample' in the context of apps you use daily 
# (like Instagram followers, Zomato restaurants, or Flipkart products). For each, 
# clearly define what would be considered the population and what would be a sample.

population = [
    "Domino's", "McDonald's", "Subway", "Pizza Hut",
    "La Pinoz", "Honest", "KFC", "Burger King",
    "Gwalia", "Jay Bhavani"
]


sample = random.sample(population,4)
print(f"population data is : == {population}")
print(f"sample data is :== {sample}")


'''so their is the population has multiple ahemdabad restaurant but sample was their some of 
part so that is the population and sample
'''
# Out:
# population data is : == ["Domino's", "McDonald's", 'Subway', 'Pizza Hut', 'La Pinoz', 'Honest', 'KFC', 'Burger King', 'Gwalia', 'Jay Bhavani']
# sample data is :== ['La Pinoz', 'Pizza Hut', 'Subway', 'Gwalia']
# 'so their is the population has multiple ahemdabad restaurant but sample was their some of \npart so that is the population and sample\n'

# %%
# 2.  Write a Python script that simulates random sampling: given a list of 1000 fake user IDs (e.g., user1 to user1000), 
# select 50 random users to simulate a survey sample. Print the selected user IDs.<br><br><em><strong>Hint:</strong> 
# Use the random.sample() function from Python's random module.</em>

population =list(range(2023001,2023100))
print(f"population data is :== {population}")
sample=random.sample(population,10)
print(f"sample data is :== {sample}")
# Out:
# population data is :== [2023001, 2023002, 2023003, 2023004, 2023005, 2023006, 2023007, 2023008, 2023009, 2023010, 2023011, 2023012, 2023013, 2023014, 2023015, 2023016, 2023017, 2023018, 2023019, 2023020, 2023021, 2023022, 2023023, 2023024, 2023025, 2023026, 2023027, 2023028, 2023029, 2023030, 2023031, 2023032, 2023033, 2023034, 2023035, 2023036, 2023037, 2023038, 2023039, 2023040, 2023041, 2023042, 2023043, 2023044, 2023045, 2023046, 2023047, 2023048, 2023049, 2023050, 2023051, 2023052, 2023053, 2023054, 2023055, 2023056, 2023057, 2023058, 2023059, 2023060, 2023061, 2023062, 2023063, 2023064, 2023065, 2023066, 2023067, 2023068, 2023069, 2023070, 2023071, 2023072, 2023073, 2023074, 2023075, 2023076, 2023077, 2023078, 2023079, 2023080, 2023081, 2023082, 2023083, 2023084, 2023085, 2023086, 2023087, 2023088, 2023089, 2023090, 2023091, 2023092, 2023093, 2023094, 2023095, 2023096, 2023097, 2023098, 2023099]
# ...

# %%
# 3. Imagine you are analyzing food delivery times on Swiggy. Explain in 2-3 sentences why you would use sampling 
# instead of collecting data from every single order ever made.

delivery_time = (np.random.randint(20,60,1000))
pdata = list(delivery_time)
sample = random.sample(pdata,10)
sample

print(f"population data length= {len(pdata)}")
print(f"sample data length= {len(sample)}")

'''In this program, we created a population of 1000 Swiggy delivery orders and selected a sample of 10 orders using
   random sampling. Instead of analyzing every single order, we use a sample to estimate the average delivery time,
   which saves time, reduces computational cost, and provides faster insights about the overall delivery performance'''
# Out:
# population data length= 1000
# sample data length= 10
# 'In this program, we created a population of 1000 Swiggy delivery orders and selected a sample of 10 orders using\n   random sampling. Instead of analyzing every single order, we use a sample to estimate the average delivery time,\n   which saves time, reduces computational cost, and provides faster insights about the overall delivery performance'

# %%
# 4.Given this scenario: A survey about music preferences is only sent to users who recently streamed Bollywood songs on Spotify.
# Identify and explain the type of bias this introduces in the sample.



all_users=all_users = [
    "Bollywood", "Pop", "Rock", "Jazz", "Classical",
    "Hip-Hop", "Punjabi", "Bollywood", "Pop", "Rock",
    "Bollywood", "Jazz", "Hip-Hop", "Classical", "Punjabi",
    "Bollywood", "Pop", "Rock", "Jazz", "Hip-Hop"
]

sample = [ i for i in all_users if i == 'Bollywood']
print(len(all_users))
print(sample)
# Out:
# ['Bollywood', 'Pop', 'Rock', 'Jazz', 'Classical', 'Hip-Hop', 'Punjabi', 'Bollywood', 'Pop', 'Rock', 'Bollywood', 'Jazz', 'Hip-Hop', 'Classical', 'Punjabi', 'Bollywood', 'Pop', 'Rock', 'Jazz', 'Hip-Hop']
# ['Bollywood', 'Bollywood', 'Bollywood', 'Bollywood']

# %%
# 5. Choose any two types of sampling (for example: random sampling, stratified sampling, systematic sampling, cluster sampling).
#  For each, describe how you would use it to select a sample of users from BookMyShow to study movie booking habits.

#random sampling

book_myshow_age = list(range(1,101))
sample = random.sample(book_myshow_age,25)

print("random sampling data = ",sample)


#stratified sampling

book_my_show_city = {
    'Ahemdabad':[22,44,45,88,90,33],
    'Rajkot':[22,44,77,100,22,66],
    'surat':[11,55,78,89,33,22],
    'saputara':[44,333,222,111]
}

first = random.sample(book_my_show_city['Ahemdabad'],2)
secound =random.sample(book_my_show_city['saputara'],3)

first.extend(secound)
print("stratifid sampling = ",first)
# Out:
# random sampling data =  [57, 18, 69, 21, 58, 16, 100, 76, 82, 46, 95, 51, 22, 9, 37, 1, 23, 7, 33, 65, 80, 91, 54, 47, 15]
# stratifid sampling =  [90, 44, 333, 111, 222]
